# %% [markdown]
# # data loader

# %%
import cv2
import numpy as np
import pandas as pd
from collections import defaultdict
import sys
import xml.etree.ElementTree as ET
from xml.dom import minidom
import requests
import tarfile

from os import path
from PIL import Image
from PIL import ImageFont, ImageDraw
from glob import glob
from matplotlib import pyplot as plt

from matplotlib.patches import  Rectangle
from PIL import ImageFont, ImageDraw
import tensorflow as tf
import ast

# %%
def convert_String_to_array(string_array):
    nested_list = ast.literal_eval(string_array)

    return nested_list

def normalize_img(img):
    #norm_img = (img - img.min()) / (img.max() - img.min())
    norm_img = np.array(img,dtype= np.float32)/255.0
    return norm_img

# %%
def get_cell_list(row, col):
    cell_list = []
    cord_list = []
    for idx_row, box_row in enumerate(row):
        x1_row, y1_row , x2_row, y2_row = box_row
        for idx_col, box_col in enumerate(col):
            x1_col, y1_col, x2_col, y2_col = box_col

            update_cell = [idx_row, idx_col, x1_col, y1_row, x2_col, y2_row]
            update_cord = [idx_row, idx_col]
            cell_list.append(update_cell)
            cord_list.append(update_cord)
    current_len = len(cell_list)
    cell_list = np.array(cell_list)
    # pad = (0, 2500-current_len)
    # cell_list_padded = np.pad(cell_list, (pad, (0,0)), mode= 'constant', constant_values= 0)
    return cell_list, cord_list

# %%
def box_feature_map(cell_list):
    new_cell_list = []
    for box in cell_list:
        x_pos, y_pos , x1 , y1 , x2 , y2 = box
        x1 = int((x1*64)/256)
        y1 = int((y1*64)/256)
        x2 = int((x2*64)/256)
        y2 = int((y2*64)/256)
        new_box = [x_pos, y_pos, x1, y1, x2, y2]
        new_cell_list.append(new_box)
    new_cell_list = np.array(new_cell_list)
    return new_cell_list

# %%
def load_data_input(file_name, col_bbox_list, row_bbox_list):
    col = convert_String_to_array(col_bbox_list)
    col =np.array(col)
    col = col[0]

    row= convert_String_to_array(row_bbox_list)
    row =np.array(row)
    row = row[0]


    img_path  = data_path + file_name + '.jpg'
    image = Image.open(img_path)
    image_np = np.array(image)
    image_np = cv2.resize(image_np, (256,256))
    image_np = np.array(image_np)

    cell_list, cord_list = get_cell_list(row, col)
    feature_map_cell = box_feature_map(cell_list) 


    return image_np, feature_map_cell

# %%
def pad_array_row(x):
    padded = np.pad(x, ((1,0), (0,0)), mode= 'constant', constant_values= 0)
    return padded
def pad_array_col(x):
    padded = np.pad(x, ((0,0), (1,0)), mode= 'constant', constant_values= 0)
    return padded
def load_data_gt(file_name):
    row_arr = np.load(saved_txt_row_path + file_name + ".npy")
    col_arr = np.load(saved_txt_col_path + file_name + ".npy")
    
    row_arr_padded = pad_array_row(row_arr)
    col_arr_padded = pad_array_col(col_arr)
    row_arr_final = row_arr_padded.flatten()
    col_arr_final = col_arr_padded.flatten()

    return row_arr_final, col_arr_final

# %%
class DataGenerator(tf.keras.utils.Sequence) :
    def __init__(self, data_row, data_col , batch_size= 1,dim = 256, shuffle=True ):
        self.data_row= data_row
        self.data_col = data_col
        self.indices= self.data_row.index.tolist()
        self.batch_size = batch_size
        self.dim = dim
        self.shuffle = shuffle
        self.on_epoch_end()
    def __len__(self):
        return int(np.ceil(len(self.data_row) / self.batch_size))
    def __getitem__(self, index):
        if (index + 1) * self.batch_size > len(self.indices):
            self.batch_size = len(self.indices) - index * self.batch_size
        index = self.indices[index * self.batch_size : (index + 1) * self.batch_size]
        batch = [self.indices[k] for k in index]
        image_input_batch, feature_map_bbox_batch, gt_row_batch, gt_col_batch = self.data_generation(batch)
        return {"image" : image_input_batch, "bbox" : feature_map_bbox_batch} , {"row" :  gt_row_batch, "col": gt_col_batch}

    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))
        if self.shuffle == True:
            np.random.shuffle(self.index)

    def data_generation(self, batch):
        image_input_batch = np.empty((self.batch_size, self.dim , self.dim , 3))
        # feature_map_bbox_batch = np.empty((self.batch_size, 2500, 4))
        # gt_row_batch = np.empty((self.batch_size, 900))
        # gt_col_batch = np.empty((self.batch_size, 900))

        file_name = self.data_col.iloc[0][0]
        col_bbox_list = self.data_col.iloc[0][1]
        row_bbox_list = self.data_row.iloc[0][1]

        image_resized , feature_map_bbox = load_data_input(file_name, col_bbox_list, row_bbox_list)
        image_resized = normalize_img(image_resized)
        row_arr_padded, col_arr_padded = load_data_gt(file_name)

        image_input_batch[0] = image_resized
        feature_map_bbox_batch =np.expand_dims(feature_map_bbox , axis=0)

        gt_row_batch = np.expand_dims(row_arr_padded, axis= 0 )
        # gt_row_batch = np.expand_dims(gt_row_batch, axis= -1 )
        gt_col_batch = np.expand_dims(col_arr_padded, axis= 0 ) 
        # gt_col_batch = np.expand_dims(gt_col_batch, axis= -1 )


        return image_input_batch, feature_map_bbox_batch, gt_row_batch, gt_col_batch

# %% [markdown]
# # model

# %%
import os
import numpy as np 
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate , LeakyReLU, BatchNormalization , ReLU , Embedding , LayerNormalization, MultiHeadAttention, Add
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
# from keras.engine import Layer, InputSpec
# from tensorflow.keras.engine.topology import Layer
import keras.backend as K
import pandas as pd
import numpy as np
import ast
import cv2
# import imutils
import matplotlib.pyplot as plt
from PIL import Image

# %%
MAX_ = 30

# %%
def identity_block(input_tensor, kernel_size, filter_num, stage):
    x = layers.Conv2D(filter_num, (1,1))(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filter_num, kernel_size, padding ='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

# %%
def conv_block(input_tensor,kernel_size,filter_num,stage,strides=(2, 2)):
    x = layers.Conv2D(filter_num, (1, 1), strides=strides)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filter_num, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    shortcut = layers.Conv2D(filter_num, (1, 1), strides=strides)(input_tensor)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)

    return x

# %%
def res_net_18(input_tensor):
    #input_tensor = Input(shape=(height, width, depth))

    x = layers.Conv2D(64, (7, 7),strides=(2, 2),padding='same',name='input')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding = 'same')(x)

    x = conv_block(x, 3, 64, stage=2, strides=(1, 1))
    c2 = identity_block(x, 3, 64, stage=2)

    x = conv_block(c2, 3, 128, stage=3)
    c3 = identity_block(x, 3, 128, stage=3)

    x = conv_block(c3, 3, 256, stage=4)
    c4 = identity_block(x, 3, 256, stage=4)

    x = conv_block(c4, 3, 512, stage=5)
    c5 = identity_block(x, 3, 512, stage=5)

    #model = Model(inputs=input_tensor , outputs = x)
    return c2, c3 , c4 ,c5

# %%
def lateral(x, out_channels):
    x = layers.Conv2D(out_channels, (1, 1), padding='same')(x)
    return  x
def upsampling_add(x,y):
    b,h,w,c = y.shape
    x = tf.image.resize(x, (h,w), method='bilinear')
    return layers.add([x,y])
def smooth(x):
    x = Conv2D(256, kernel_size = 3, strides = 1, padding ='same')(x)
    return x

# %%
def transformer_encoder(inputs, num_heads, mlp_dim, dropout_rate):
    # Layer normalization 1
    # x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    # Multi-head attention
    x = layers.MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1], dropout=dropout_rate)(x, x)
    # Skip connection 1
    x = layers.Add()([x, inputs])

    # Layer normalization 2
    y = layers.LayerNormalization(epsilon=1e-6)(x)
    # MLP (feed-forward network)
    y = layers.Dense(mlp_dim, activation=tf.nn.gelu)(y)
    y = layers.Dropout(dropout_rate)(y)
    y = layers.Dense(inputs.shape[-1])(y)
    # Skip connection 2
    return layers.Add()([y, x])

# %%
class Roi_Pooling(layers.Layer):
    def __init__(self, pool_size, **kwargs):
        super(Roi_Pooling, self).__init__(**kwargs)
        self.pool_size = pool_size
    def call(self, feature_map, rois):
        """
        feature _map  = [b,h,w,c]
        rois = [x_loc, y_loc , x1 ,y1, x2, y2]

        """
        b,h,w,c = feature_map.get_shape().as_list()
        outputs = []
        x1 = rois[:,2]/w
        y1 = rois[:,3]/h
        x2 = rois[:,4]/w
        y2 = rois[:,5]/h
        boxes = tf.stack([y1, x1, y2, x2], axis=1)
        batch_indices = tf.zeros(shape=(tf.shape(rois)[0]), dtype=tf.int32)
        
        pooled_feature = tf.image.crop_and_resize(feature_map, boxes, box_indices=batch_indices, crop_size=[self.pool_size[0], self.pool_size[1]], method="bilinear")
        return pooled_feature

    def get_config(self):
        config = super().get_config()
        config.update({'pool_size' : self.pool_size})
        return config

# %%
class PatchEncoder(layers.Layer):
    def __init__(self , num_patches = (MAX_*MAX_), projection_dims = 512,**kwargs ):
        super(PatchEncoder, self).__init__(**kwargs)
        self.num_patches = num_patches
        self.num_dims  = projection_dims
        self.x_positional_embeddings = Embedding(input_dim = num_patches, output_dim = 256)
        self.y_positional_embeddings = Embedding(input_dim = num_patches, output_dim = 256)

    def call(self, x_tensor , rois):
        """
        x: input tensor after roi pooling ( shape = ((M x N), 512))
        position embedding: (shape = (50, 512))
        """

        x = tf.reduce_max(rois[0,:,1])
        y = tf.reduce_max(rois[0,:,0])


        x = tf.cast(x, dtype='int32')
        y = tf.cast(y, dtype='int32')
        # print(f'row :{row}')
        # print(f'col: {col}')
        col = tf.range(x+1)
        row = tf.range(y+1)

        x_embedding = self.x_positional_embeddings(col)
        y_embedding = self.y_positional_embeddings(row)

        x_embedding = tf.expand_dims(x_embedding, axis= 0)
        y_embedding = tf.expand_dims(y_embedding, axis= 1)

        x_embedding =tf.broadcast_to(x_embedding,(tf.shape(y_embedding)[0], tf.shape(x_embedding)[1], tf.shape(x_embedding)[2]))
        y_embedding = tf.broadcast_to(y_embedding, (tf.shape(y_embedding)[0], tf.shape(x_embedding)[1], tf.shape(y_embedding)[2]))

        pos_ = tf.concat([y_embedding, x_embedding], axis= -1) # (M, N, 512)
        # print(pos_.shape)
        final_pos = tf.reshape(pos_, (-1 , tf.shape(pos_)[2]))

        return_tensor = x_tensor + final_pos
        return return_tensor

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_paches": self.num_patches,
            "d": self.num_dims,
        })
        return config

# %%
def mlp(x):
    out = tf.keras.layers.Dense(512, activation = 'relu')(x)
    out = tf.keras.layers.Dense(512)(out)
    return out
def transformer_encoder(x):
    skip_1 = x
    
    x = MultiHeadAttention(num_heads=10, key_dim=512)(x, x)
    x = Add()([x, skip_1])
    x = LayerNormalization()(x)
    skip_2 = x
    
    x = mlp(x)
    x = Add()([x, skip_2])
    x = LayerNormalization()(x)
    return x

# %%
def predict_mlp(x_tensor):
    x = tf.keras.layers.Dense(512, activation ='relu')(x_tensor)
    x = tf.keras.layers.Dense(512)(x)
    x = tf.keras.layers.Dense(1,activation='sigmoid')(x)
    return x

# %%
INPUT_SHAPE =(256,256,3)
input_tensor = Input(shape=(INPUT_SHAPE), batch_size= 1 , name= "image" )
input_cell_box = Input(shape=(None,6), batch_size= 1 , name="bbox")  
c2, c3 , c4 ,c5  = res_net_18(input_tensor)

m5 = lateral(c5, 256)

m4  = upsampling_add(m5,lateral(c4,256) )
m3  = upsampling_add(m4,lateral(c3,256) )
m2  = upsampling_add(m3,lateral(c2,256) )

p5 = smooth(m5)
p4 = smooth(m4)
p3 = smooth(m3)
p2 = smooth(m2)

p2_2 = Conv2D(128, kernel_size = 3, strides = 1, padding ='same', name = "p2_2")(p2)

# print(p2_2.shape)
crops = Roi_Pooling(pool_size=(7,7))(p2_2, input_cell_box[0])

embedded_patches= tf.keras.layers.Flatten()(crops)
embedded_patches= layers.Dense(512)(embedded_patches)

encoded = PatchEncoder()(embedded_patches , input_cell_box) 

x = tf.expand_dims(encoded, axis = 0)

# cls_token = tf.zeros((1, 1, 512))

# x = tf.concat([cls_token, encoded], axis = 1)

for _ in range(10):
    x = transformer_encoder(x)
x = tf.squeeze(x, axis = 0)
row  = predict_mlp(x)
row = tf.expand_dims(row, axis= 0, name='row')
col = predict_mlp(x)
col = tf.expand_dims(col, axis= 0, name='col')
input_ = [input_tensor, input_cell_box]
out = {'row' : row,'col': col}

model = Model(inputs = input_, outputs = out)

model.compile(loss= {'row' : 'binary_crossentropy', 'col' : 'binary_crossentropy'}, optimizer='adam')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(1, 256, 256, 3)]   0           []
#
#  input (Conv2D)                 (1, 128, 128, 64)    9472        ['image[0][0]']
#
#  batch_normalization (BatchNorm  (1, 128, 128, 64)   256         ['input[0][0]']
#  alization)
#
#  activation (Activation)        (1, 128, 128, 64)    0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (1, 64, 64, 64)      0           ['activation[0][0]']
#
#  conv2d (Conv2D)                (1, 64, 64, 64)      4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (1, 64, 64, 64)     256         ['conv2d[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (1, 64, 64, 64)      0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (1, 64, 64, 64)      36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (1, 64, 64, 64)     256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (1, 64, 64, 64)      4160        ['max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (1, 64, 64, 64)      0           ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (1, 64, 64, 64)     256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (1, 64, 64, 64)      0           ['activation_2[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_3 (Activation)      (1, 64, 64, 64)      0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (1, 64, 64, 64)      4160        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (1, 64, 64, 64)     256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (1, 64, 64, 64)      0           ['batch_normalization_4[0][0]']
#
#  conv2d_4 (Conv2D)              (1, 64, 64, 64)      36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (1, 64, 64, 64)     256         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (1, 64, 64, 64)      0           ['batch_normalization_5[0][0]']
#
#  add_1 (Add)                    (1, 64, 64, 64)      0           ['activation_5[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (1, 64, 64, 64)      0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (1, 32, 32, 128)     8320        ['activation_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (1, 32, 32, 128)    512         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (1, 32, 32, 128)     0           ['batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (1, 32, 32, 128)     147584      ['activation_7[0][0]']
#
#  batch_normalization_7 (BatchNo  (1, 32, 32, 128)    512         ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (1, 32, 32, 128)     8320        ['activation_6[0][0]']
#
#  activation_8 (Activation)      (1, 32, 32, 128)     0           ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (1, 32, 32, 128)    512         ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (1, 32, 32, 128)     0           ['activation_8[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (1, 32, 32, 128)     0           ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)              (1, 32, 32, 128)     16512       ['activation_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (1, 32, 32, 128)    512         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (1, 32, 32, 128)     0           ['batch_normalization_9[0][0]']
#
#  conv2d_9 (Conv2D)              (1, 32, 32, 128)     147584      ['activation_10[0][0]']
#
#  batch_normalization_10 (BatchN  (1, 32, 32, 128)    512         ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (1, 32, 32, 128)     0           ['batch_normalization_10[0][0]']
#
#  add_3 (Add)                    (1, 32, 32, 128)     0           ['activation_11[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_12 (Activation)     (1, 32, 32, 128)     0           ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)             (1, 16, 16, 256)     33024       ['activation_12[0][0]']
#
#  batch_normalization_11 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (1, 16, 16, 256)     0           ['batch_normalization_11[0][0]']
#
#  conv2d_11 (Conv2D)             (1, 16, 16, 256)     590080      ['activation_13[0][0]']
#
#  batch_normalization_12 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  conv2d_12 (Conv2D)             (1, 16, 16, 256)     33024       ['activation_12[0][0]']
#
#  activation_14 (Activation)     (1, 16, 16, 256)     0           ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_12[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (1, 16, 16, 256)     0           ['activation_14[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  activation_15 (Activation)     (1, 16, 16, 256)     0           ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)             (1, 16, 16, 256)     65792       ['activation_15[0][0]']
#
#  batch_normalization_14 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (1, 16, 16, 256)     0           ['batch_normalization_14[0][0]']
#
#  conv2d_14 (Conv2D)             (1, 16, 16, 256)     590080      ['activation_16[0][0]']
#
#  batch_normalization_15 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (1, 16, 16, 256)     0           ['batch_normalization_15[0][0]']
#
#  add_5 (Add)                    (1, 16, 16, 256)     0           ['activation_17[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (1, 16, 16, 256)     0           ['add_5[0][0]']
#
#  conv2d_15 (Conv2D)             (1, 8, 8, 512)       131584      ['activation_18[0][0]']
#
#  batch_normalization_16 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (1, 8, 8, 512)       0           ['batch_normalization_16[0][0]']
#
#  conv2d_16 (Conv2D)             (1, 8, 8, 512)       2359808     ['activation_19[0][0]']
#
#  batch_normalization_17 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_16[0][0]']
#  ormalization)
#
#  conv2d_17 (Conv2D)             (1, 8, 8, 512)       131584      ['activation_18[0][0]']
#
#  activation_20 (Activation)     (1, 8, 8, 512)       0           ['batch_normalization_17[0][0]']
#
#  batch_normalization_18 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_17[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (1, 8, 8, 512)       0           ['activation_20[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_21 (Activation)     (1, 8, 8, 512)       0           ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)             (1, 8, 8, 512)       262656      ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (1, 8, 8, 512)       0           ['batch_normalization_19[0][0]']
#
#  conv2d_19 (Conv2D)             (1, 8, 8, 512)       2359808     ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (1, 8, 8, 512)       0           ['batch_normalization_20[0][0]']
#
#  add_7 (Add)                    (1, 8, 8, 512)       0           ['activation_23[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_24 (Activation)     (1, 8, 8, 512)       0           ['add_7[0][0]']
#
#  conv2d_20 (Conv2D)             (1, 8, 8, 256)       131328      ['activation_24[0][0]']
#
#  tf.image.resize (TFOpLambda)   (1, 16, 16, 256)     0           ['conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (1, 16, 16, 256)     65792       ['activation_18[0][0]']
#
#  add_8 (Add)                    (1, 16, 16, 256)     0           ['tf.image.resize[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  tf.image.resize_1 (TFOpLambda)  (1, 32, 32, 256)    0           ['add_8[0][0]']
#
#  conv2d_22 (Conv2D)             (1, 32, 32, 256)     33024       ['activation_12[0][0]']
#
#  add_9 (Add)                    (1, 32, 32, 256)     0           ['tf.image.resize_1[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  tf.image.resize_2 (TFOpLambda)  (1, 64, 64, 256)    0           ['add_9[0][0]']
#
#  conv2d_23 (Conv2D)             (1, 64, 64, 256)     16640       ['activation_6[0][0]']
#
#  add_10 (Add)                   (1, 64, 64, 256)     0           ['tf.image.resize_2[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  conv2d_27 (Conv2D)             (1, 64, 64, 256)     590080      ['add_10[0][0]']
#
#  bbox (InputLayer)              [(1, None, 6)]       0           []
#
#  p2_2 (Conv2D)                  (1, 64, 64, 128)     295040      ['conv2d_27[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 6)           0           ['bbox[0][0]']
#  ingOpLambda)
#
#  roi__pooling (Roi_Pooling)     (None, 7, 7, 128)    0           ['p2_2[0][0]',
#                                                                   'tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  flatten (Flatten)              (None, 6272)         0           ['roi__pooling[0][0]']
#
#  dense (Dense)                  (None, 512)          3211776     ['flatten[0][0]']
#
#  patch_encoder (PatchEncoder)   (None, 512)          460800      ['dense[0][0]',
#                                                                   'bbox[0][0]']
#
#  tf.expand_dims (TFOpLambda)    (1, None, 512)       0           ['patch_encoder[0][0]']
#
#  multi_head_attention (MultiHea  (1, None, 512)      10501632    ['tf.expand_dims[0][0]',
#  dAttention)                                                      'tf.expand_dims[0][0]']
#
#  add_11 (Add)                   (1, None, 512)       0           ['multi_head_attention[0][0]',
#                                                                   'tf.expand_dims[0][0]']
#
#  layer_normalization (LayerNorm  (1, None, 512)      1024        ['add_11[0][0]']
#  alization)
#
#  dense_1 (Dense)                (1, None, 512)       262656      ['layer_normalization[0][0]']
#
#  dense_2 (Dense)                (1, None, 512)       262656      ['dense_1[0][0]']
#
#  add_12 (Add)                   (1, None, 512)       0           ['dense_2[0][0]',
#                                                                   'layer_normalization[0][0]']
#
#  layer_normalization_1 (LayerNo  (1, None, 512)      1024        ['add_12[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (1, None, 512)      10501632    ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  add_13 (Add)                   (1, None, 512)       0           ['multi_head_attention_1[0][0]',
#                                                                   'layer_normalization_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (1, None, 512)      1024        ['add_13[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (1, None, 512)       262656      ['layer_normalization_2[0][0]']
#
#  dense_4 (Dense)                (1, None, 512)       262656      ['dense_3[0][0]']
#
#  add_14 (Add)                   (1, None, 512)       0           ['dense_4[0][0]',
#                                                                   'layer_normalization_2[0][0]']
#
#  layer_normalization_3 (LayerNo  (1, None, 512)      1024        ['add_14[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (1, None, 512)      10501632    ['layer_normalization_3[0][0]',
#  eadAttention)                                                    'layer_normalization_3[0][0]']
#
#  add_15 (Add)                   (1, None, 512)       0           ['multi_head_attention_2[0][0]',
#                                                                   'layer_normalization_3[0][0]']
#
#  layer_normalization_4 (LayerNo  (1, None, 512)      1024        ['add_15[0][0]']
#  rmalization)
#
#  dense_5 (Dense)                (1, None, 512)       262656      ['layer_normalization_4[0][0]']
#
#  dense_6 (Dense)                (1, None, 512)       262656      ['dense_5[0][0]']
#
#  add_16 (Add)                   (1, None, 512)       0           ['dense_6[0][0]',
#                                                                   'layer_normalization_4[0][0]']
#
#  layer_normalization_5 (LayerNo  (1, None, 512)      1024        ['add_16[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (1, None, 512)      10501632    ['layer_normalization_5[0][0]',
#  eadAttention)                                                    'layer_normalization_5[0][0]']
#
#  add_17 (Add)                   (1, None, 512)       0           ['multi_head_attention_3[0][0]',
#                                                                   'layer_normalization_5[0][0]']
#
#  layer_normalization_6 (LayerNo  (1, None, 512)      1024        ['add_17[0][0]']
#  rmalization)
#
#  dense_7 (Dense)                (1, None, 512)       262656      ['layer_normalization_6[0][0]']
#
#  dense_8 (Dense)                (1, None, 512)       262656      ['dense_7[0][0]']
#
#  add_18 (Add)                   (1, None, 512)       0           ['dense_8[0][0]',
#                                                                   'layer_normalization_6[0][0]']
#
#  layer_normalization_7 (LayerNo  (1, None, 512)      1024        ['add_18[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (1, None, 512)      10501632    ['layer_normalization_7[0][0]',
#  eadAttention)                                                    'layer_normalization_7[0][0]']
#
#  add_19 (Add)                   (1, None, 512)       0           ['multi_head_attention_4[0][0]',
#                                                                   'layer_normalization_7[0][0]']
#
#  layer_normalization_8 (LayerNo  (1, None, 512)      1024        ['add_19[0][0]']
#  rmalization)
#
#  dense_9 (Dense)                (1, None, 512)       262656      ['layer_normalization_8[0][0]']
#
#  dense_10 (Dense)               (1, None, 512)       262656      ['dense_9[0][0]']
#
#  add_20 (Add)                   (1, None, 512)       0           ['dense_10[0][0]',
#                                                                   'layer_normalization_8[0][0]']
#
#  layer_normalization_9 (LayerNo  (1, None, 512)      1024        ['add_20[0][0]']
#  rmalization)
#
#  multi_head_attention_5 (MultiH  (1, None, 512)      10501632    ['layer_normalization_9[0][0]',
#  eadAttention)                                                    'layer_normalization_9[0][0]']
#
#  add_21 (Add)                   (1, None, 512)       0           ['multi_head_attention_5[0][0]',
#                                                                   'layer_normalization_9[0][0]']
#
#  layer_normalization_10 (LayerN  (1, None, 512)      1024        ['add_21[0][0]']
#  ormalization)
#
#  dense_11 (Dense)               (1, None, 512)       262656      ['layer_normalization_10[0][0]']
#
#  dense_12 (Dense)               (1, None, 512)       262656      ['dense_11[0][0]']
#
#  add_22 (Add)                   (1, None, 512)       0           ['dense_12[0][0]',
#                                                                   'layer_normalization_10[0][0]']
#
#  layer_normalization_11 (LayerN  (1, None, 512)      1024        ['add_22[0][0]']
#  ormalization)
#
#  multi_head_attention_6 (MultiH  (1, None, 512)      10501632    ['layer_normalization_11[0][0]',
#  eadAttention)                                                    'layer_normalization_11[0][0]']
#
#  add_23 (Add)                   (1, None, 512)       0           ['multi_head_attention_6[0][0]',
#                                                                   'layer_normalization_11[0][0]']
#
#  layer_normalization_12 (LayerN  (1, None, 512)      1024        ['add_23[0][0]']
#  ormalization)
#
#  dense_13 (Dense)               (1, None, 512)       262656      ['layer_normalization_12[0][0]']
#
#  dense_14 (Dense)               (1, None, 512)       262656      ['dense_13[0][0]']
#
#  add_24 (Add)                   (1, None, 512)       0           ['dense_14[0][0]',
#                                                                   'layer_normalization_12[0][0]']
#
#  layer_normalization_13 (LayerN  (1, None, 512)      1024        ['add_24[0][0]']
#  ormalization)
#
#  multi_head_attention_7 (MultiH  (1, None, 512)      10501632    ['layer_normalization_13[0][0]',
#  eadAttention)                                                    'layer_normalization_13[0][0]']
#
#  add_25 (Add)                   (1, None, 512)       0           ['multi_head_attention_7[0][0]',
#                                                                   'layer_normalization_13[0][0]']
#
#  layer_normalization_14 (LayerN  (1, None, 512)      1024        ['add_25[0][0]']
#  ormalization)
#
#  dense_15 (Dense)               (1, None, 512)       262656      ['layer_normalization_14[0][0]']
#
#  dense_16 (Dense)               (1, None, 512)       262656      ['dense_15[0][0]']
#
#  add_26 (Add)                   (1, None, 512)       0           ['dense_16[0][0]',
#                                                                   'layer_normalization_14[0][0]']
#
#  layer_normalization_15 (LayerN  (1, None, 512)      1024        ['add_26[0][0]']
#  ormalization)
#
#  multi_head_attention_8 (MultiH  (1, None, 512)      10501632    ['layer_normalization_15[0][0]',
#  eadAttention)                                                    'layer_normalization_15[0][0]']
#
#  add_27 (Add)                   (1, None, 512)       0           ['multi_head_attention_8[0][0]',
#                                                                   'layer_normalization_15[0][0]']
#
#  layer_normalization_16 (LayerN  (1, None, 512)      1024        ['add_27[0][0]']
#  ormalization)
#
#  dense_17 (Dense)               (1, None, 512)       262656      ['layer_normalization_16[0][0]']
#
#  dense_18 (Dense)               (1, None, 512)       262656      ['dense_17[0][0]']
#
#  add_28 (Add)                   (1, None, 512)       0           ['dense_18[0][0]',
#                                                                   'layer_normalization_16[0][0]']
#
#  layer_normalization_17 (LayerN  (1, None, 512)      1024        ['add_28[0][0]']
#  ormalization)
#
#  multi_head_attention_9 (MultiH  (1, None, 512)      10501632    ['layer_normalization_17[0][0]',
#  eadAttention)                                                    'layer_normalization_17[0][0]']
#
#  add_29 (Add)                   (1, None, 512)       0           ['multi_head_attention_9[0][0]',
#                                                                   'layer_normalization_17[0][0]']
#
#  layer_normalization_18 (LayerN  (1, None, 512)      1024        ['add_29[0][0]']
#  ormalization)
#
#  dense_19 (Dense)               (1, None, 512)       262656      ['layer_normalization_18[0][0]']
#
#  dense_20 (Dense)               (1, None, 512)       262656      ['dense_19[0][0]']
#
#  add_30 (Add)                   (1, None, 512)       0           ['dense_20[0][0]',
#                                                                   'layer_normalization_18[0][0]']
#
#  layer_normalization_19 (LayerN  (1, None, 512)      1024        ['add_30[0][0]']
#  ormalization)
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 512)         0           ['layer_normalization_19[0][0]']
#  da)
#
#  dense_24 (Dense)               (None, 512)          262656      ['tf.compat.v1.squeeze[0][0]']
#
#  dense_21 (Dense)               (None, 512)          262656      ['tf.compat.v1.squeeze[0][0]']
#
#  dense_25 (Dense)               (None, 512)          262656      ['dense_24[0][0]']
#
#  dense_22 (Dense)               (None, 512)          262656      ['dense_21[0][0]']
#
#  dense_26 (Dense)               (None, 1)            513         ['dense_25[0][0]']
#
#  dense_23 (Dense)               (None, 1)            513         ['dense_22[0][0]']
#
#  tf.expand_dims_2 (TFOpLambda)  (1, None, 1)         0           ['dense_26[0][0]']
#
#  tf.expand_dims_1 (TFOpLambda)  (1, None, 1)         0           ['dense_23[0][0]']
#
# ==================================================================================================
# Total params: 123,147,074
# Trainable params: 123,137,346
# Non-trainable params: 9,728
# __________________________________________________________________________________________________
