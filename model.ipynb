# %%
import os
import numpy as np 
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate , LeakyReLU, BatchNormalization , ReLU , Embedding , LayerNormalization, MultiHeadAttention, Add
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
# from keras.engine import Layer, InputSpec
# from tensorflow.keras.engine.topology import Layer
import keras.backend as K
import pandas as pd
import numpy as np
import ast
import cv2
# import imutils
import matplotlib.pyplot as plt
from PIL import Image

# %%
data_path =       'D:/learn/de cuong/code/split/data_generated/image/'
source_xml_path = 'D:/learn/de cuong/code/split/data_pubtables_1M/PubTables-1M-Structure_Annotations_Test/'
source_word_path ='D:/learn/de cuong/code/split/data_pubtables_1M/PubTables-1M-Structure_Table_Words/'


saved_txt_row_path ="D:/learn/de cuong/code/merge/data_merge_cell/row/"
saved_txt_col_path ="D:/learn/de cuong/code/merge/data_merge_cell/col/"

# %%
def convert_String_to_array(string_array):
    nested_list = ast.literal_eval(string_array)

    return nested_list

# %%
def identity_block(input_tensor, kernel_size, filter_num, stage):
    x = layers.Conv2D(filter_num, (1,1))(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filter_num, kernel_size, padding ='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

# %%
def conv_block(input_tensor,kernel_size,filter_num,stage,strides=(2, 2)):
    x = layers.Conv2D(filter_num, (1, 1), strides=strides)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filter_num, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    shortcut = layers.Conv2D(filter_num, (1, 1), strides=strides)(input_tensor)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)

    return x

# %%
def res_net_18(input_tensor):
    #input_tensor = Input(shape=(height, width, depth))

    x = layers.Conv2D(64, (7, 7),strides=(2, 2),padding='same',name='input')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding = 'same')(x)

    x = conv_block(x, 3, 64, stage=2, strides=(1, 1))
    c2 = identity_block(x, 3, 64, stage=2)

    x = conv_block(c2, 3, 128, stage=3)
    c3 = identity_block(x, 3, 128, stage=3)

    x = conv_block(c3, 3, 256, stage=4)
    c4 = identity_block(x, 3, 256, stage=4)

    x = conv_block(c4, 3, 512, stage=5)
    c5 = identity_block(x, 3, 512, stage=5)

    #model = Model(inputs=input_tensor , outputs = x)
    return c2, c3 , c4 ,c5

# %%
def lateral(x, out_channels):
    x = layers.Conv2D(out_channels, (1, 1), padding='same')(x)
    return  x
def upsampling_add(x,y):
    b,h,w,c = y.shape
    x = tf.image.resize(x, (h,w), method='bilinear')
    return layers.add([x,y])
def smooth(x):
    x = Conv2D(256, kernel_size = 3, strides = 1, padding ='same')(x)
    return x

# %%
def transformer_encoder(inputs, num_heads, mlp_dim, dropout_rate):
    # Layer normalization 1
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    # Multi-head attention
    x = layers.MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1], dropout=dropout_rate)(x, x)
    # Skip connection 1
    x = layers.Add()([x, inputs])

    # Layer normalization 2
    y = layers.LayerNormalization(epsilon=1e-6)(x)
    # MLP (feed-forward network)
    y = layers.Dense(mlp_dim, activation=tf.nn.gelu)(y)
    y = layers.Dropout(dropout_rate)(y)
    y = layers.Dense(inputs.shape[-1])(y)
    # Skip connection 2
    return layers.Add()([y, x])

# %%
data_col = pd.read_csv('data_col.csv')
data_row = pd.read_csv('data_row.csv')

# %%
class Roi_Pooling(layers.Layer):
    def __init__(self, pool_size, **kwargs):
        super(Roi_Pooling, self).__init__(**kwargs)
        self.pool_size = pool_size
    def call(self, feature_map, rois):
        """
        feature _map  = [b,h,w,c]
        rois = [x1 ,y1, x2, y2]

        """
        b,h,w,c = feature_map.get_shape().as_list()
        batch_indices = tf.zeros(shape=tf.shape(rois)[0], dtype= tf.int32)
        boxes = rois[:,1:]
        pooles_feature = tf.image.crop_and_resize(feature_map, boxes, box_indices = batch_indices, crop_size=[self.pool_size[0], self.pool_size[1]] )

        return pooles_feature

    def get_config(self):
        config = super().get_config()
        config.update({'pool_size' : self.pool_size})
        return config

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches = 2500, projection_dims = 512,**kwargs ):
        super(PatchEncoder, self).__init__(**kwargs)
        self.num_patches = num_patches
        self.num_dims  = projection_dims

        self.x_positional_embeddings = Embedding(input_dim = num_patches, output_dim = projection_dims)
        self.y_positional_embeddings = Embedding(input_dim = num_patches, output_dim = projection_dims)

    def call(self, x):
        """
        x: input tensor after roi pooling ( shape = (1, 2500, 512))
        position embedding: (shape = (50, 512))
        """
        encoded_list = []
        x_position = tf.range(0,limit=self.num_patches, delta=1)
        y_position = tf.range(0,limit=self.num_patches, delta=1)

        for i in range(self.num_patches):
            x_idx = int(i%50)
            y_idx = int(i//50)
            encoded = self.x_positional_embeddings(x_position[x_idx]) + self.y_positional_embeddings(y_position[y_idx]) + x[0,i,:]  # x[i] is the patch embedding
            encoded_list.append(tf.expand_dims(encoded, axis=0))
        encoded_full = K.concatenate(encoded_list, axis=0)
        return encoded_full

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_paches": self.num_patches,
            "d": self.num_dims,
        })
        return config

# %%
def mlp(x):
    x = Dense(3072, activation="gelu")(x)
    x = Dropout(0.1)(x)
    x = Dense(512)(x)
    x = Dropout(0.1)(x)
    return x
def transformer_encoder(x):
    skip_1 = x
    x = LayerNormalization()(x)
    x = MultiHeadAttention(
        num_heads=10, key_dim=512
    )(x, x)
    x = Add()([x, skip_1])

    skip_2 = x
    x = LayerNormalization()(x)
    x = mlp(x)
    x = Add()([x, skip_2])

    return x

# %%
INPUT_SHAPE =(1024,1024,3)
input_tensor = Input(shape=(INPUT_SHAPE), batch_size= 1 )
input_cell_box = Input(shape=(5), batch_size= 1)  
c2, c3 , c4 ,c5  = res_net_18(input_tensor)

m5 = lateral(c5, 256)

m4  = upsampling_add(m5,lateral(c4,256) )
m3  = upsampling_add(m4,lateral(c3,256) )
m2  = upsampling_add(m3,lateral(c2,256) )

p5 = smooth(m5)
p4 = smooth(m4)
p3 = smooth(m3)
p2 = smooth(m2)

p2_2 = Conv2D(128, kernel_size = 3, strides = 1, padding ='same', name = "p2_2")(p2)

crops = Roi_Pooling(pool_size=(7,7))(p2_2, input_cell_box)

#position embedded ing
embedded_patches= tf.keras.layers.Flatten()(crops)

embedded_patches= layers.Dense(512)(embedded_patches)
embedded_patches = layers.Activation('ReLU')(embedded_patches)
embedded_patches= layers.Dense(512)(embedded_patches)

# encoded = PatchEncoder()(embedded_patches) # 50*50 patches, each patch has 512 dims
# encoded = tf.expand_dims(encoded, axis = 0)

# cls_token = tf.zeros((1, 1, 512))

# x = tf.concat([cls_token, encoded], axis = 1)
# print("here")
# for _ in range(10):
#     x = transformer_encoder(x)
# x = LayerNormalization()(x) 
# x = x[:, 0, :] 
# x = Dropout(0.1)(x)
# x = Dense(50*50, activation="softmax")(x)

# x_sub = Dense(50*50, activation="softmax")(x)
# x_sub = Dropout(0.1)(x_sub)
# row = Dense(50*50, activation="softmax" , name = "out_row")(x_sub)
# col = Dense(50*50, activation="softmax" , name = "out_col")(x_sub)

input_ = [input_tensor, input_cell_box]
# out = [row, col]

model = Model(inputs = input_, outputs = embedded_patches)

# %%
crops.shape
# Out:
# TensorShape([1, 7, 7, 128])

# %%
model.compile(loss= {'row' : 'binary_crossentropy', 'col' : 'binary_crossentropy'}, optimizer='adam')

# %%
model.output_shape
# Out:
# (1, 512)

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(1, 1024, 1024, 3)  0           []
#                                 ]
#
#  input (Conv2D)                 (1, 512, 512, 64)    9472        ['input_17[0][0]']
#
#  batch_normalization_168 (Batch  (1, 512, 512, 64)   256         ['input[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (1, 512, 512, 64)    0           ['batch_normalization_168[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (1, 256, 256, 64)   0           ['activation_208[0][0]']
#
#  conv2d_224 (Conv2D)            (1, 256, 256, 64)    4160        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_169 (Batch  (1, 256, 256, 64)   256         ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (1, 256, 256, 64)    0           ['batch_normalization_169[0][0]']
#
#  conv2d_225 (Conv2D)            (1, 256, 256, 64)    36928       ['activation_209[0][0]']
#
#  batch_normalization_170 (Batch  (1, 256, 256, 64)   256         ['conv2d_225[0][0]']
#  Normalization)
#
#  conv2d_226 (Conv2D)            (1, 256, 256, 64)    4160        ['max_pooling2d_8[0][0]']
#
#  activation_210 (Activation)    (1, 256, 256, 64)    0           ['batch_normalization_170[0][0]']
#
#  batch_normalization_171 (Batch  (1, 256, 256, 64)   256         ['conv2d_226[0][0]']
#  Normalization)
#
#  add_152 (Add)                  (1, 256, 256, 64)    0           ['activation_210[0][0]',
#                                                                   'batch_normalization_171[0][0]']
#
#  activation_211 (Activation)    (1, 256, 256, 64)    0           ['add_152[0][0]']
#
#  conv2d_227 (Conv2D)            (1, 256, 256, 64)    4160        ['activation_211[0][0]']
#
#  batch_normalization_172 (Batch  (1, 256, 256, 64)   256         ['conv2d_227[0][0]']
#  Normalization)
#
#  activation_212 (Activation)    (1, 256, 256, 64)    0           ['batch_normalization_172[0][0]']
#
#  conv2d_228 (Conv2D)            (1, 256, 256, 64)    36928       ['activation_212[0][0]']
#
#  batch_normalization_173 (Batch  (1, 256, 256, 64)   256         ['conv2d_228[0][0]']
#  Normalization)
#
#  activation_213 (Activation)    (1, 256, 256, 64)    0           ['batch_normalization_173[0][0]']
#
#  add_153 (Add)                  (1, 256, 256, 64)    0           ['activation_213[0][0]',
#                                                                   'activation_211[0][0]']
#
#  activation_214 (Activation)    (1, 256, 256, 64)    0           ['add_153[0][0]']
#
#  conv2d_229 (Conv2D)            (1, 128, 128, 128)   8320        ['activation_214[0][0]']
#
#  batch_normalization_174 (Batch  (1, 128, 128, 128)  512         ['conv2d_229[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (1, 128, 128, 128)   0           ['batch_normalization_174[0][0]']
#
#  conv2d_230 (Conv2D)            (1, 128, 128, 128)   147584      ['activation_215[0][0]']
#
#  batch_normalization_175 (Batch  (1, 128, 128, 128)  512         ['conv2d_230[0][0]']
#  Normalization)
#
#  conv2d_231 (Conv2D)            (1, 128, 128, 128)   8320        ['activation_214[0][0]']
#
#  activation_216 (Activation)    (1, 128, 128, 128)   0           ['batch_normalization_175[0][0]']
#
#  batch_normalization_176 (Batch  (1, 128, 128, 128)  512         ['conv2d_231[0][0]']
#  Normalization)
#
#  add_154 (Add)                  (1, 128, 128, 128)   0           ['activation_216[0][0]',
#                                                                   'batch_normalization_176[0][0]']
#
#  activation_217 (Activation)    (1, 128, 128, 128)   0           ['add_154[0][0]']
#
#  conv2d_232 (Conv2D)            (1, 128, 128, 128)   16512       ['activation_217[0][0]']
#
#  batch_normalization_177 (Batch  (1, 128, 128, 128)  512         ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (1, 128, 128, 128)   0           ['batch_normalization_177[0][0]']
#
#  conv2d_233 (Conv2D)            (1, 128, 128, 128)   147584      ['activation_218[0][0]']
#
#  batch_normalization_178 (Batch  (1, 128, 128, 128)  512         ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (1, 128, 128, 128)   0           ['batch_normalization_178[0][0]']
#
#  add_155 (Add)                  (1, 128, 128, 128)   0           ['activation_219[0][0]',
#                                                                   'activation_217[0][0]']
#
#  activation_220 (Activation)    (1, 128, 128, 128)   0           ['add_155[0][0]']
#
#  conv2d_234 (Conv2D)            (1, 64, 64, 256)     33024       ['activation_220[0][0]']
#
#  batch_normalization_179 (Batch  (1, 64, 64, 256)    1024        ['conv2d_234[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (1, 64, 64, 256)     0           ['batch_normalization_179[0][0]']
#
#  conv2d_235 (Conv2D)            (1, 64, 64, 256)     590080      ['activation_221[0][0]']
#
#  batch_normalization_180 (Batch  (1, 64, 64, 256)    1024        ['conv2d_235[0][0]']
#  Normalization)
#
#  conv2d_236 (Conv2D)            (1, 64, 64, 256)     33024       ['activation_220[0][0]']
#
#  activation_222 (Activation)    (1, 64, 64, 256)     0           ['batch_normalization_180[0][0]']
#
#  batch_normalization_181 (Batch  (1, 64, 64, 256)    1024        ['conv2d_236[0][0]']
#  Normalization)
#
#  add_156 (Add)                  (1, 64, 64, 256)     0           ['activation_222[0][0]',
#                                                                   'batch_normalization_181[0][0]']
#
#  activation_223 (Activation)    (1, 64, 64, 256)     0           ['add_156[0][0]']
#
#  conv2d_237 (Conv2D)            (1, 64, 64, 256)     65792       ['activation_223[0][0]']
#
#  batch_normalization_182 (Batch  (1, 64, 64, 256)    1024        ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (1, 64, 64, 256)     0           ['batch_normalization_182[0][0]']
#
#  conv2d_238 (Conv2D)            (1, 64, 64, 256)     590080      ['activation_224[0][0]']
#
#  batch_normalization_183 (Batch  (1, 64, 64, 256)    1024        ['conv2d_238[0][0]']
#  Normalization)
#
#  activation_225 (Activation)    (1, 64, 64, 256)     0           ['batch_normalization_183[0][0]']
#
#  add_157 (Add)                  (1, 64, 64, 256)     0           ['activation_225[0][0]',
#                                                                   'activation_223[0][0]']
#
#  activation_226 (Activation)    (1, 64, 64, 256)     0           ['add_157[0][0]']
#
#  conv2d_239 (Conv2D)            (1, 32, 32, 512)     131584      ['activation_226[0][0]']
#
#  batch_normalization_184 (Batch  (1, 32, 32, 512)    2048        ['conv2d_239[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (1, 32, 32, 512)     0           ['batch_normalization_184[0][0]']
#
#  conv2d_240 (Conv2D)            (1, 32, 32, 512)     2359808     ['activation_227[0][0]']
#
#  batch_normalization_185 (Batch  (1, 32, 32, 512)    2048        ['conv2d_240[0][0]']
#  Normalization)
#
#  conv2d_241 (Conv2D)            (1, 32, 32, 512)     131584      ['activation_226[0][0]']
#
#  activation_228 (Activation)    (1, 32, 32, 512)     0           ['batch_normalization_185[0][0]']
#
#  batch_normalization_186 (Batch  (1, 32, 32, 512)    2048        ['conv2d_241[0][0]']
#  Normalization)
#
#  add_158 (Add)                  (1, 32, 32, 512)     0           ['activation_228[0][0]',
#                                                                   'batch_normalization_186[0][0]']
#
#  activation_229 (Activation)    (1, 32, 32, 512)     0           ['add_158[0][0]']
#
#  conv2d_242 (Conv2D)            (1, 32, 32, 512)     262656      ['activation_229[0][0]']
#
#  batch_normalization_187 (Batch  (1, 32, 32, 512)    2048        ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (1, 32, 32, 512)     0           ['batch_normalization_187[0][0]']
#
#  conv2d_243 (Conv2D)            (1, 32, 32, 512)     2359808     ['activation_230[0][0]']
#
#  batch_normalization_188 (Batch  (1, 32, 32, 512)    2048        ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_231 (Activation)    (1, 32, 32, 512)     0           ['batch_normalization_188[0][0]']
#
#  add_159 (Add)                  (1, 32, 32, 512)     0           ['activation_231[0][0]',
#                                                                   'activation_229[0][0]']
#
#  activation_232 (Activation)    (1, 32, 32, 512)     0           ['add_159[0][0]']
#
#  conv2d_244 (Conv2D)            (1, 32, 32, 256)     131328      ['activation_232[0][0]']
#
#  tf.image.resize_24 (TFOpLambda  (1, 64, 64, 256)    0           ['conv2d_244[0][0]']
#  )
#
#  conv2d_245 (Conv2D)            (1, 64, 64, 256)     65792       ['activation_226[0][0]']
#
#  add_160 (Add)                  (1, 64, 64, 256)     0           ['tf.image.resize_24[0][0]',
#                                                                   'conv2d_245[0][0]']
#
#  tf.image.resize_25 (TFOpLambda  (1, 128, 128, 256)  0           ['add_160[0][0]']
#  )
#
#  conv2d_246 (Conv2D)            (1, 128, 128, 256)   33024       ['activation_220[0][0]']
#
#  add_161 (Add)                  (1, 128, 128, 256)   0           ['tf.image.resize_25[0][0]',
#                                                                   'conv2d_246[0][0]']
#
#  tf.image.resize_26 (TFOpLambda  (1, 256, 256, 256)  0           ['add_161[0][0]']
#  )
#
#  conv2d_247 (Conv2D)            (1, 256, 256, 256)   16640       ['activation_214[0][0]']
#
#  add_162 (Add)                  (1, 256, 256, 256)   0           ['tf.image.resize_26[0][0]',
#                                                                   'conv2d_247[0][0]']
#
#  conv2d_251 (Conv2D)            (1, 256, 256, 256)   590080      ['add_162[0][0]']
#
#  p2_2 (Conv2D)                  (1, 256, 256, 128)   295040      ['conv2d_251[0][0]']
#
#  input_18 (InputLayer)          [(1, 2500, 4)]       0           []
#
#  roi__pooling_8 (Roi_Pooling)   (2500, 7, 7, 128)    0           ['p2_2[0][0]',
#                                                                   'input_18[0][0]']
#
#  tf.reshape_8 (TFOpLambda)      (1, 2500, 6272)      0           ['roi__pooling_8[0][0]']
#
#  dense_83 (Dense)               (1, 2500, 512)       3211776     ['tf.reshape_8[0][0]']
#
#  activation_233 (Activation)    (1, 2500, 512)       0           ['dense_83[0][0]']
#
#  dense_84 (Dense)               (1, 2500, 512)       262656      ['activation_233[0][0]']
#
#  patch_encoder_8 (PatchEncoder)  (2500, 512)         2560000     ['dense_84[0][0]']
#
#  tf.expand_dims_8 (TFOpLambda)  (1, 2500, 512)       0           ['patch_encoder_8[0][0]']
#
#  tf.concat_8 (TFOpLambda)       (1, 2501, 512)       0           ['tf.expand_dims_8[0][0]']
#
#  layer_normalization_68 (LayerN  (1, 2501, 512)      1024        ['tf.concat_8[0][0]']
#  ormalization)
#
#  multi_head_attention_33 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_68[0][0]',
#  HeadAttention)                                                   'layer_normalization_68[0][0]']
#
#  add_163 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_33[0][0]',
#                                                                   'tf.concat_8[0][0]']
#
#  layer_normalization_69 (LayerN  (1, 2501, 512)      1024        ['add_163[0][0]']
#  ormalization)
#
#  dense_85 (Dense)               (1, 2501, 3072)      1575936     ['layer_normalization_69[0][0]']
#
#  dropout_65 (Dropout)           (1, 2501, 3072)      0           ['dense_85[0][0]']
#
#  dense_86 (Dense)               (1, 2501, 512)       1573376     ['dropout_65[0][0]']
#
#  dropout_66 (Dropout)           (1, 2501, 512)       0           ['dense_86[0][0]']
#
#  add_164 (Add)                  (1, 2501, 512)       0           ['dropout_66[0][0]',
#                                                                   'add_163[0][0]']
#
#  layer_normalization_70 (LayerN  (1, 2501, 512)      1024        ['add_164[0][0]']
#  ormalization)
#
#  multi_head_attention_34 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_70[0][0]',
#  HeadAttention)                                                   'layer_normalization_70[0][0]']
#
#  add_165 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_34[0][0]',
#                                                                   'add_164[0][0]']
#
#  layer_normalization_71 (LayerN  (1, 2501, 512)      1024        ['add_165[0][0]']
#  ormalization)
#
#  dense_87 (Dense)               (1, 2501, 3072)      1575936     ['layer_normalization_71[0][0]']
#
#  dropout_67 (Dropout)           (1, 2501, 3072)      0           ['dense_87[0][0]']
#
#  dense_88 (Dense)               (1, 2501, 512)       1573376     ['dropout_67[0][0]']
#
#  dropout_68 (Dropout)           (1, 2501, 512)       0           ['dense_88[0][0]']
#
#  add_166 (Add)                  (1, 2501, 512)       0           ['dropout_68[0][0]',
#                                                                   'add_165[0][0]']
#
#  layer_normalization_72 (LayerN  (1, 2501, 512)      1024        ['add_166[0][0]']
#  ormalization)
#
#  multi_head_attention_35 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_72[0][0]',
#  HeadAttention)                                                   'layer_normalization_72[0][0]']
#
#  add_167 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_35[0][0]',
#                                                                   'add_166[0][0]']
#
#  layer_normalization_73 (LayerN  (1, 2501, 512)      1024        ['add_167[0][0]']
#  ormalization)
#
#  dense_89 (Dense)               (1, 2501, 3072)      1575936     ['layer_normalization_73[0][0]']
#
#  dropout_69 (Dropout)           (1, 2501, 3072)      0           ['dense_89[0][0]']
#
#  dense_90 (Dense)               (1, 2501, 512)       1573376     ['dropout_69[0][0]']
#
#  dropout_70 (Dropout)           (1, 2501, 512)       0           ['dense_90[0][0]']
#
#  add_168 (Add)                  (1, 2501, 512)       0           ['dropout_70[0][0]',
#                                                                   'add_167[0][0]']
#
#  layer_normalization_74 (LayerN  (1, 2501, 512)      1024        ['add_168[0][0]']
#  ormalization)
#
#  multi_head_attention_36 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_74[0][0]',
#  HeadAttention)                                                   'layer_normalization_74[0][0]']
#
#  add_169 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_36[0][0]',
#                                                                   'add_168[0][0]']
#
#  layer_normalization_75 (LayerN  (1, 2501, 512)      1024        ['add_169[0][0]']
#  ormalization)
#
#  dense_91 (Dense)               (1, 2501, 3072)      1575936     ['layer_normalization_75[0][0]']
#
#  dropout_71 (Dropout)           (1, 2501, 3072)      0           ['dense_91[0][0]']
#
#  dense_92 (Dense)               (1, 2501, 512)       1573376     ['dropout_71[0][0]']
#
#  dropout_72 (Dropout)           (1, 2501, 512)       0           ['dense_92[0][0]']
#
#  add_170 (Add)                  (1, 2501, 512)       0           ['dropout_72[0][0]',
#                                                                   'add_169[0][0]']
#
#  layer_normalization_76 (LayerN  (1, 2501, 512)      1024        ['add_170[0][0]']
#  ormalization)
#
#  multi_head_attention_37 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_76[0][0]',
#  HeadAttention)                                                   'layer_normalization_76[0][0]']
#
#  add_171 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_37[0][0]',
#                                                                   'add_170[0][0]']
#
#  layer_normalization_77 (LayerN  (1, 2501, 512)      1024        ['add_171[0][0]']
#  ormalization)
#
#  dense_93 (Dense)               (1, 2501, 3072)      1575936     ['layer_normalization_77[0][0]']
#
#  dropout_73 (Dropout)           (1, 2501, 3072)      0           ['dense_93[0][0]']
#
#  dense_94 (Dense)               (1, 2501, 512)       1573376     ['dropout_73[0][0]']
#
#  dropout_74 (Dropout)           (1, 2501, 512)       0           ['dense_94[0][0]']
#
#  add_172 (Add)                  (1, 2501, 512)       0           ['dropout_74[0][0]',
#                                                                   'add_171[0][0]']
#
#  layer_normalization_78 (LayerN  (1, 2501, 512)      1024        ['add_172[0][0]']
#  ormalization)
#
#  multi_head_attention_38 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_78[0][0]',
#  HeadAttention)                                                   'layer_normalization_78[0][0]']
#
#  add_173 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_38[0][0]',
#                                                                   'add_172[0][0]']
#
#  layer_normalization_79 (LayerN  (1, 2501, 512)      1024        ['add_173[0][0]']
#  ormalization)
#
#  dense_95 (Dense)               (1, 2501, 3072)      1575936     ['layer_normalization_79[0][0]']
#
#  dropout_75 (Dropout)           (1, 2501, 3072)      0           ['dense_95[0][0]']
#
#  dense_96 (Dense)               (1, 2501, 512)       1573376     ['dropout_75[0][0]']
#
#  dropout_76 (Dropout)           (1, 2501, 512)       0           ['dense_96[0][0]']
#
#  add_174 (Add)                  (1, 2501, 512)       0           ['dropout_76[0][0]',
#                                                                   'add_173[0][0]']
#
#  layer_normalization_80 (LayerN  (1, 2501, 512)      1024        ['add_174[0][0]']
#  ormalization)
#
#  multi_head_attention_39 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_80[0][0]',
#  HeadAttention)                                                   'layer_normalization_80[0][0]']
#
#  add_175 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_39[0][0]',
#                                                                   'add_174[0][0]']
#
#  layer_normalization_81 (LayerN  (1, 2501, 512)      1024        ['add_175[0][0]']
#  ormalization)
#
#  dense_97 (Dense)               (1, 2501, 3072)      1575936     ['layer_normalization_81[0][0]']
#
#  dropout_77 (Dropout)           (1, 2501, 3072)      0           ['dense_97[0][0]']
#
#  dense_98 (Dense)               (1, 2501, 512)       1573376     ['dropout_77[0][0]']
#
#  dropout_78 (Dropout)           (1, 2501, 512)       0           ['dense_98[0][0]']
#
#  add_176 (Add)                  (1, 2501, 512)       0           ['dropout_78[0][0]',
#                                                                   'add_175[0][0]']
#
#  layer_normalization_82 (LayerN  (1, 2501, 512)      1024        ['add_176[0][0]']
#  ormalization)
#
#  multi_head_attention_40 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_82[0][0]',
#  HeadAttention)                                                   'layer_normalization_82[0][0]']
#
#  add_177 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_40[0][0]',
#                                                                   'add_176[0][0]']
#
#  layer_normalization_83 (LayerN  (1, 2501, 512)      1024        ['add_177[0][0]']
#  ormalization)
#
#  dense_99 (Dense)               (1, 2501, 3072)      1575936     ['layer_normalization_83[0][0]']
#
#  dropout_79 (Dropout)           (1, 2501, 3072)      0           ['dense_99[0][0]']
#
#  dense_100 (Dense)              (1, 2501, 512)       1573376     ['dropout_79[0][0]']
#
#  dropout_80 (Dropout)           (1, 2501, 512)       0           ['dense_100[0][0]']
#
#  add_178 (Add)                  (1, 2501, 512)       0           ['dropout_80[0][0]',
#                                                                   'add_177[0][0]']
#
#  layer_normalization_84 (LayerN  (1, 2501, 512)      1024        ['add_178[0][0]']
#  ormalization)
#
#  multi_head_attention_41 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_84[0][0]',
#  HeadAttention)                                                   'layer_normalization_84[0][0]']
#
#  add_179 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_41[0][0]',
#                                                                   'add_178[0][0]']
#
#  layer_normalization_85 (LayerN  (1, 2501, 512)      1024        ['add_179[0][0]']
#  ormalization)
#
#  dense_101 (Dense)              (1, 2501, 3072)      1575936     ['layer_normalization_85[0][0]']
#
#  dropout_81 (Dropout)           (1, 2501, 3072)      0           ['dense_101[0][0]']
#
#  dense_102 (Dense)              (1, 2501, 512)       1573376     ['dropout_81[0][0]']
#
#  dropout_82 (Dropout)           (1, 2501, 512)       0           ['dense_102[0][0]']
#
#  add_180 (Add)                  (1, 2501, 512)       0           ['dropout_82[0][0]',
#                                                                   'add_179[0][0]']
#
#  layer_normalization_86 (LayerN  (1, 2501, 512)      1024        ['add_180[0][0]']
#  ormalization)
#
#  multi_head_attention_42 (Multi  (1, 2501, 512)      10501632    ['layer_normalization_86[0][0]',
#  HeadAttention)                                                   'layer_normalization_86[0][0]']
#
#  add_181 (Add)                  (1, 2501, 512)       0           ['multi_head_attention_42[0][0]',
#                                                                   'add_180[0][0]']
#
#  layer_normalization_87 (LayerN  (1, 2501, 512)      1024        ['add_181[0][0]']
#  ormalization)
#
#  dense_103 (Dense)              (1, 2501, 3072)      1575936     ['layer_normalization_87[0][0]']
#
#  dropout_83 (Dropout)           (1, 2501, 3072)      0           ['dense_103[0][0]']
#
#  dense_104 (Dense)              (1, 2501, 512)       1573376     ['dropout_83[0][0]']
#
#  dropout_84 (Dropout)           (1, 2501, 512)       0           ['dense_104[0][0]']
#
#  add_182 (Add)                  (1, 2501, 512)       0           ['dropout_84[0][0]',
#                                                                   'add_181[0][0]']
#
#  layer_normalization_88 (LayerN  (1, 2501, 512)      1024        ['add_182[0][0]']
#  ormalization)
#
#  tf.__operators__.getitem_2 (Sl  (1, 512)            0           ['layer_normalization_88[0][0]']
#  icingOpLambda)
#
#  dropout_85 (Dropout)           (1, 512)             0           ['tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  dense_105 (Dense)              (1, 2500)            1282500     ['dropout_85[0][0]']
#
#  dense_106 (Dense)              (1, 2500)            6252500     ['dense_105[0][0]']
#
#  dropout_86 (Dropout)           (1, 2500)            0           ['dense_106[0][0]']
#
#  dense_107 (Dense)              (1, 2500)            6252500     ['dropout_86[0][0]']
#
#  dense_108 (Dense)              (1, 2500)            6252500     ['dropout_86[0][0]']
#
# ==================================================================================================
# Total params: 170,738,304
# Trainable params: 170,728,576
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %%
# from tensorflow.keras.utils import plot_model
# plot_model(model, to_file='model.png', show_shapes=True)
