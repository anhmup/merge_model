# %%
import os
import numpy as np 
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate , LeakyReLU, BatchNormalization , ReLU , Embedding , LayerNormalization, MultiHeadAttention, Add
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
# from keras.engine import Layer, InputSpec
# from tensorflow.keras.engine.topology import Layer
import keras.backend as K
import pandas as pd
import numpy as np
import ast
import cv2
# import imutils
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # model

# %%
def identity_block(input_tensor, kernel_size, filter_num, stage):
    x = layers.Conv2D(filter_num, (1,1))(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filter_num, kernel_size, padding ='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

# %%
def conv_block(input_tensor,kernel_size,filter_num,stage,strides=(2, 2)):
    x = layers.Conv2D(filter_num, (1, 1), strides=strides)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filter_num, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    shortcut = layers.Conv2D(filter_num, (1, 1), strides=strides)(input_tensor)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)

    return x

# %%
def res_net_18(input_tensor):
    #input_tensor = Input(shape=(height, width, depth))

    x = layers.Conv2D(64, (7, 7),strides=(2, 2),padding='same',name='input')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding = 'same')(x)

    x = conv_block(x, 3, 64, stage=2, strides=(1, 1))
    c2 = identity_block(x, 3, 64, stage=2)

    x = conv_block(c2, 3, 128, stage=3)
    c3 = identity_block(x, 3, 128, stage=3)

    x = conv_block(c3, 3, 256, stage=4)
    c4 = identity_block(x, 3, 256, stage=4)

    x = conv_block(c4, 3, 512, stage=5)
    c5 = identity_block(x, 3, 512, stage=5)

    #model = Model(inputs=input_tensor , outputs = x)
    return c2, c3 , c4 ,c5

# %%
def lateral(x, out_channels):
    x = layers.Conv2D(out_channels, (1, 1), padding='same')(x)
    return  x
def upsampling_add(x,y):
    b,h,w,c = y.shape
    x = tf.image.resize(x, (h,w), method='bilinear')
    return layers.add([x,y])
def smooth(x):
    x = Conv2D(256, kernel_size = 3, strides = 1, padding ='same')(x)
    return x

# %%
def transformer_encoder(inputs, num_heads, mlp_dim, dropout_rate):
    # Layer normalization 1
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    # Multi-head attention
    x = layers.MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1], dropout=dropout_rate)(x, x)
    # Skip connection 1
    x = layers.Add()([x, inputs])

    # Layer normalization 2
    y = layers.LayerNormalization(epsilon=1e-6)(x)
    # MLP (feed-forward network)
    y = layers.Dense(mlp_dim, activation=tf.nn.gelu)(y)
    y = layers.Dropout(dropout_rate)(y)
    y = layers.Dense(inputs.shape[-1])(y)
    # Skip connection 2
    return layers.Add()([y, x])

# %%
class Roi_Pooling(layers.Layer):
    def __init__(self, pool_size, **kwargs):
        super(Roi_Pooling, self).__init__(**kwargs)
        self.pool_size = pool_size
    def call(self, feature_map, rois):
        """
        feature _map  = [b,h,w,c]
        rois = [x_loc, y_loc , x1 ,y1, x2, y2]

        """
        b,h,w,c = feature_map.get_shape().as_list()
        outputs = []
        x1 = rois[:,2]/w
        y1 = rois[:,3]/h
        x2 = rois[:,4]/w
        y2 = rois[:,5]/h
        boxes = tf.stack([y1, x1, y2, x2], axis=1)
        batch_indices = tf.zeros(shape=(tf.shape(rois)[0]), dtype=tf.int32)
        
        pooled_feature = tf.image.crop_and_resize(feature_map, boxes, box_indices=batch_indices, crop_size=[self.pool_size[0], self.pool_size[1]], method="bilinear")
        return pooled_feature

    def get_config(self):
        config = super().get_config()
        config.update({'pool_size' : self.pool_size})
        return config

# %%
MAX_ = 30

# %%
class PatchEncoder(layers.Layer):
    def __init__(self , num_patches = (MAX_*MAX_), projection_dims = 512,**kwargs ):
        super(PatchEncoder, self).__init__(**kwargs)
        self.num_patches = num_patches
        self.num_dims  = projection_dims
        self.x_positional_embeddings = Embedding(input_dim = num_patches, output_dim = projection_dims)
        self.y_positional_embeddings = Embedding(input_dim = num_patches, output_dim = projection_dims)

    def call(self, x , rois):
        """
        x: input tensor after roi pooling ( shape = ((M x N), 512))
        position embedding: (shape = (50, 512))
        """
        # x = tf.expand_dims(x, axis=0)
        # print(x.shape)
        pos_list = []
        x_position = tf.range(0,limit=self.num_patches, delta=1)
        y_position = tf.range(0,limit=self.num_patches, delta=1)
        ngang = tf.reduce_max(rois[:,1])
        doc  = tf.reduce_max(rois[:,0])
        num_ = tf.shape(x)[0]
        pad_len = (MAX_*MAX_) - tf.shape(x)[0]
        x_padded = tf.pad(x, [[0, pad_len],[0,0]], constant_values=0)
        # print("here")
        # print(x_padded.shape)
        # pos_ = tf.zeros(shape=tf.shape(x_padded))
        for i in range(MAX_*MAX_):
            x_idx = tf.math.floormod(i, MAX_)
            y_idx = tf.math.floordiv(i, MAX_)
            x_pos = self.x_positional_embeddings(x_idx) # (512,)
            y_pos = self.y_positional_embeddings(y_idx) # (512,)
            pos_embedded = x_pos + y_pos
            pos_list.append(pos_embedded)
        pos_ = tf.stack(pos_list,axis=0)

        print(f'pos_ {pos_.shape}')
        encoded_full = x_padded + pos_
        return encoded_full

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_paches": self.num_patches,
            "d": self.num_dims,
        })
        return config

# %%
def mlp(x):
    x = Dense(3072, activation="gelu")(x)
    x = Dropout(0.1)(x)
    x = Dense(512)(x)
    x = Dropout(0.1)(x)
    return x
def transformer_encoder(x):
    skip_1 = x
    x = LayerNormalization()(x)
    x = MultiHeadAttention(
        num_heads=10, key_dim=512
    )(x, x)
    x = Add()([x, skip_1])

    skip_2 = x
    x = LayerNormalization()(x)
    x = mlp(x)
    x = Add()([x, skip_2])

    return x

# %%
INPUT_SHAPE =(256,256,3)
input_tensor = Input(shape=(INPUT_SHAPE), batch_size= 1 , name= "image" )
input_cell_box = Input(shape=(None,6), batch_size= 1 , name="bbox")  
c2, c3 , c4 ,c5  = res_net_18(input_tensor)

m5 = lateral(c5, 256)

m4  = upsampling_add(m5,lateral(c4,256) )
m3  = upsampling_add(m4,lateral(c3,256) )
m2  = upsampling_add(m3,lateral(c2,256) )

p5 = smooth(m5)
p4 = smooth(m4)
p3 = smooth(m3)
p2 = smooth(m2)

p2_2 = Conv2D(128, kernel_size = 3, strides = 1, padding ='same', name = "p2_2")(p2)


crops = Roi_Pooling(pool_size=(7,7))(p2_2, input_cell_box[0])

# #position embedded ing
embedded_patches= tf.keras.layers.Flatten()(crops)
embedded_patches= layers.Dense(512)(embedded_patches)
embedded_patches = layers.Activation('ReLU')(embedded_patches)
embedded_patches= layers.Dense(512)(embedded_patches)

encoded = PatchEncoder()(embedded_patches , input_cell_box) # 50*50 patches, each patch has 512 dims

encoded = tf.expand_dims(encoded, axis = 0)

cls_token = tf.zeros((1, 1, 512))

x = tf.concat([cls_token, encoded], axis = 1)

for _ in range(10):
    x = transformer_encoder(x)
x = LayerNormalization()(x) 
x = x[:, 0, :] 
x = Dropout(0.1)(x)
x_sub = Dense((MAX_*MAX_), activation="softmax")(x)

row = Dense((MAX_*MAX_), activation="softmax" , name = "row")(x_sub)
col = Dense((MAX_*MAX_), activation="softmax" , name = "col")(x_sub)

input_ = [input_tensor, input_cell_box]
out = [row, col]

model = Model(inputs = input_, outputs = out)
# Out:
# pos_ (900, 512)

# %%
model.compile(loss= {'row' : 'binary_crossentropy', 'col' : 'binary_crossentropy'}, optimizer='adam')

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(1, 256, 256, 3)]   0           []
#
#  input (Conv2D)                 (1, 128, 128, 64)    9472        ['image[0][0]']
#
#  batch_normalization_21 (BatchN  (1, 128, 128, 64)   256         ['input[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (1, 128, 128, 64)    0           ['batch_normalization_21[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (1, 64, 64, 64)     0           ['activation_26[0][0]']
#
#  conv2d_28 (Conv2D)             (1, 64, 64, 64)      4160        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_22 (BatchN  (1, 64, 64, 64)     256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (1, 64, 64, 64)      0           ['batch_normalization_22[0][0]']
#
#  conv2d_29 (Conv2D)             (1, 64, 64, 64)      36928       ['activation_27[0][0]']
#
#  batch_normalization_23 (BatchN  (1, 64, 64, 64)     256         ['conv2d_29[0][0]']
#  ormalization)
#
#  conv2d_30 (Conv2D)             (1, 64, 64, 64)      4160        ['max_pooling2d_1[0][0]']
#
#  activation_28 (Activation)     (1, 64, 64, 64)      0           ['batch_normalization_23[0][0]']
#
#  batch_normalization_24 (BatchN  (1, 64, 64, 64)     256         ['conv2d_30[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (1, 64, 64, 64)      0           ['activation_28[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_29 (Activation)     (1, 64, 64, 64)      0           ['add_31[0][0]']
#
#  conv2d_31 (Conv2D)             (1, 64, 64, 64)      4160        ['activation_29[0][0]']
#
#  batch_normalization_25 (BatchN  (1, 64, 64, 64)     256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (1, 64, 64, 64)      0           ['batch_normalization_25[0][0]']
#
#  conv2d_32 (Conv2D)             (1, 64, 64, 64)      36928       ['activation_30[0][0]']
#
#  batch_normalization_26 (BatchN  (1, 64, 64, 64)     256         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (1, 64, 64, 64)      0           ['batch_normalization_26[0][0]']
#
#  add_32 (Add)                   (1, 64, 64, 64)      0           ['activation_31[0][0]',
#                                                                   'activation_29[0][0]']
#
#  activation_32 (Activation)     (1, 64, 64, 64)      0           ['add_32[0][0]']
#
#  conv2d_33 (Conv2D)             (1, 32, 32, 128)     8320        ['activation_32[0][0]']
#
#  batch_normalization_27 (BatchN  (1, 32, 32, 128)    512         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (1, 32, 32, 128)     0           ['batch_normalization_27[0][0]']
#
#  conv2d_34 (Conv2D)             (1, 32, 32, 128)     147584      ['activation_33[0][0]']
#
#  batch_normalization_28 (BatchN  (1, 32, 32, 128)    512         ['conv2d_34[0][0]']
#  ormalization)
#
#  conv2d_35 (Conv2D)             (1, 32, 32, 128)     8320        ['activation_32[0][0]']
#
#  activation_34 (Activation)     (1, 32, 32, 128)     0           ['batch_normalization_28[0][0]']
#
#  batch_normalization_29 (BatchN  (1, 32, 32, 128)    512         ['conv2d_35[0][0]']
#  ormalization)
#
#  add_33 (Add)                   (1, 32, 32, 128)     0           ['activation_34[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  activation_35 (Activation)     (1, 32, 32, 128)     0           ['add_33[0][0]']
#
#  conv2d_36 (Conv2D)             (1, 32, 32, 128)     16512       ['activation_35[0][0]']
#
#  batch_normalization_30 (BatchN  (1, 32, 32, 128)    512         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (1, 32, 32, 128)     0           ['batch_normalization_30[0][0]']
#
#  conv2d_37 (Conv2D)             (1, 32, 32, 128)     147584      ['activation_36[0][0]']
#
#  batch_normalization_31 (BatchN  (1, 32, 32, 128)    512         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (1, 32, 32, 128)     0           ['batch_normalization_31[0][0]']
#
#  add_34 (Add)                   (1, 32, 32, 128)     0           ['activation_37[0][0]',
#                                                                   'activation_35[0][0]']
#
#  activation_38 (Activation)     (1, 32, 32, 128)     0           ['add_34[0][0]']
#
#  conv2d_38 (Conv2D)             (1, 16, 16, 256)     33024       ['activation_38[0][0]']
#
#  batch_normalization_32 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (1, 16, 16, 256)     0           ['batch_normalization_32[0][0]']
#
#  conv2d_39 (Conv2D)             (1, 16, 16, 256)     590080      ['activation_39[0][0]']
#
#  batch_normalization_33 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_39[0][0]']
#  ormalization)
#
#  conv2d_40 (Conv2D)             (1, 16, 16, 256)     33024       ['activation_38[0][0]']
#
#  activation_40 (Activation)     (1, 16, 16, 256)     0           ['batch_normalization_33[0][0]']
#
#  batch_normalization_34 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_40[0][0]']
#  ormalization)
#
#  add_35 (Add)                   (1, 16, 16, 256)     0           ['activation_40[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_41 (Activation)     (1, 16, 16, 256)     0           ['add_35[0][0]']
#
#  conv2d_41 (Conv2D)             (1, 16, 16, 256)     65792       ['activation_41[0][0]']
#
#  batch_normalization_35 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (1, 16, 16, 256)     0           ['batch_normalization_35[0][0]']
#
#  conv2d_42 (Conv2D)             (1, 16, 16, 256)     590080      ['activation_42[0][0]']
#
#  batch_normalization_36 (BatchN  (1, 16, 16, 256)    1024        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (1, 16, 16, 256)     0           ['batch_normalization_36[0][0]']
#
#  add_36 (Add)                   (1, 16, 16, 256)     0           ['activation_43[0][0]',
#                                                                   'activation_41[0][0]']
#
#  activation_44 (Activation)     (1, 16, 16, 256)     0           ['add_36[0][0]']
#
#  conv2d_43 (Conv2D)             (1, 8, 8, 512)       131584      ['activation_44[0][0]']
#
#  batch_normalization_37 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (1, 8, 8, 512)       0           ['batch_normalization_37[0][0]']
#
#  conv2d_44 (Conv2D)             (1, 8, 8, 512)       2359808     ['activation_45[0][0]']
#
#  batch_normalization_38 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_44[0][0]']
#  ormalization)
#
#  conv2d_45 (Conv2D)             (1, 8, 8, 512)       131584      ['activation_44[0][0]']
#
#  activation_46 (Activation)     (1, 8, 8, 512)       0           ['batch_normalization_38[0][0]']
#
#  batch_normalization_39 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_45[0][0]']
#  ormalization)
#
#  add_37 (Add)                   (1, 8, 8, 512)       0           ['activation_46[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  activation_47 (Activation)     (1, 8, 8, 512)       0           ['add_37[0][0]']
#
#  conv2d_46 (Conv2D)             (1, 8, 8, 512)       262656      ['activation_47[0][0]']
#
#  batch_normalization_40 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (1, 8, 8, 512)       0           ['batch_normalization_40[0][0]']
#
#  conv2d_47 (Conv2D)             (1, 8, 8, 512)       2359808     ['activation_48[0][0]']
#
#  batch_normalization_41 (BatchN  (1, 8, 8, 512)      2048        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (1, 8, 8, 512)       0           ['batch_normalization_41[0][0]']
#
#  add_38 (Add)                   (1, 8, 8, 512)       0           ['activation_49[0][0]',
#                                                                   'activation_47[0][0]']
#
#  activation_50 (Activation)     (1, 8, 8, 512)       0           ['add_38[0][0]']
#
#  conv2d_48 (Conv2D)             (1, 8, 8, 256)       131328      ['activation_50[0][0]']
#
#  tf.image.resize_3 (TFOpLambda)  (1, 16, 16, 256)    0           ['conv2d_48[0][0]']
#
#  conv2d_49 (Conv2D)             (1, 16, 16, 256)     65792       ['activation_44[0][0]']
#
#  add_39 (Add)                   (1, 16, 16, 256)     0           ['tf.image.resize_3[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  tf.image.resize_4 (TFOpLambda)  (1, 32, 32, 256)    0           ['add_39[0][0]']
#
#  conv2d_50 (Conv2D)             (1, 32, 32, 256)     33024       ['activation_38[0][0]']
#
#  add_40 (Add)                   (1, 32, 32, 256)     0           ['tf.image.resize_4[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  tf.image.resize_5 (TFOpLambda)  (1, 64, 64, 256)    0           ['add_40[0][0]']
#
#  conv2d_51 (Conv2D)             (1, 64, 64, 256)     16640       ['activation_32[0][0]']
#
#  add_41 (Add)                   (1, 64, 64, 256)     0           ['tf.image.resize_5[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  conv2d_55 (Conv2D)             (1, 64, 64, 256)     590080      ['add_41[0][0]']
#
#  bbox (InputLayer)              [(1, None, 6)]       0           []
#
#  p2_2 (Conv2D)                  (1, 64, 64, 128)     295040      ['conv2d_55[0][0]']
#
#  tf.__operators__.getitem_2 (Sl  (None, 6)           0           ['bbox[0][0]']
#  icingOpLambda)
#
#  roi__pooling_1 (Roi_Pooling)   (None, 7, 7, 128)    0           ['p2_2[0][0]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  flatten_1 (Flatten)            (None, 6272)         0           ['roi__pooling_1[0][0]']
#
#  dense_23 (Dense)               (None, 512)          3211776     ['flatten_1[0][0]']
#
#  activation_51 (Activation)     (None, 512)          0           ['dense_23[0][0]']
#
#  dense_24 (Dense)               (None, 512)          262656      ['activation_51[0][0]']
#
#  patch_encoder_1 (PatchEncoder)  (900, 512)          921600      ['dense_24[0][0]',
#                                                                   'bbox[0][0]']
#
#  tf.expand_dims_1 (TFOpLambda)  (1, 900, 512)        0           ['patch_encoder_1[0][0]']
#
#  tf.concat_1 (TFOpLambda)       (1, 901, 512)        0           ['tf.expand_dims_1[0][0]']
#
#  layer_normalization_21 (LayerN  (1, 901, 512)       1024        ['tf.concat_1[0][0]']
#  ormalization)
#
#  multi_head_attention_10 (Multi  (1, 901, 512)       10501632    ['layer_normalization_21[0][0]',
#  HeadAttention)                                                   'layer_normalization_21[0][0]']
#
#  add_42 (Add)                   (1, 901, 512)        0           ['multi_head_attention_10[0][0]',
#                                                                   'tf.concat_1[0][0]']
#
#  layer_normalization_22 (LayerN  (1, 901, 512)       1024        ['add_42[0][0]']
#  ormalization)
#
#  dense_25 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_22[0][0]']
#
#  dropout_21 (Dropout)           (1, 901, 3072)       0           ['dense_25[0][0]']
#
#  dense_26 (Dense)               (1, 901, 512)        1573376     ['dropout_21[0][0]']
#
#  dropout_22 (Dropout)           (1, 901, 512)        0           ['dense_26[0][0]']
#
#  add_43 (Add)                   (1, 901, 512)        0           ['dropout_22[0][0]',
#                                                                   'add_42[0][0]']
#
#  layer_normalization_23 (LayerN  (1, 901, 512)       1024        ['add_43[0][0]']
#  ormalization)
#
#  multi_head_attention_11 (Multi  (1, 901, 512)       10501632    ['layer_normalization_23[0][0]',
#  HeadAttention)                                                   'layer_normalization_23[0][0]']
#
#  add_44 (Add)                   (1, 901, 512)        0           ['multi_head_attention_11[0][0]',
#                                                                   'add_43[0][0]']
#
#  layer_normalization_24 (LayerN  (1, 901, 512)       1024        ['add_44[0][0]']
#  ormalization)
#
#  dense_27 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_24[0][0]']
#
#  dropout_23 (Dropout)           (1, 901, 3072)       0           ['dense_27[0][0]']
#
#  dense_28 (Dense)               (1, 901, 512)        1573376     ['dropout_23[0][0]']
#
#  dropout_24 (Dropout)           (1, 901, 512)        0           ['dense_28[0][0]']
#
#  add_45 (Add)                   (1, 901, 512)        0           ['dropout_24[0][0]',
#                                                                   'add_44[0][0]']
#
#  layer_normalization_25 (LayerN  (1, 901, 512)       1024        ['add_45[0][0]']
#  ormalization)
#
#  multi_head_attention_12 (Multi  (1, 901, 512)       10501632    ['layer_normalization_25[0][0]',
#  HeadAttention)                                                   'layer_normalization_25[0][0]']
#
#  add_46 (Add)                   (1, 901, 512)        0           ['multi_head_attention_12[0][0]',
#                                                                   'add_45[0][0]']
#
#  layer_normalization_26 (LayerN  (1, 901, 512)       1024        ['add_46[0][0]']
#  ormalization)
#
#  dense_29 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_26[0][0]']
#
#  dropout_25 (Dropout)           (1, 901, 3072)       0           ['dense_29[0][0]']
#
#  dense_30 (Dense)               (1, 901, 512)        1573376     ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)           (1, 901, 512)        0           ['dense_30[0][0]']
#
#  add_47 (Add)                   (1, 901, 512)        0           ['dropout_26[0][0]',
#                                                                   'add_46[0][0]']
#
#  layer_normalization_27 (LayerN  (1, 901, 512)       1024        ['add_47[0][0]']
#  ormalization)
#
#  multi_head_attention_13 (Multi  (1, 901, 512)       10501632    ['layer_normalization_27[0][0]',
#  HeadAttention)                                                   'layer_normalization_27[0][0]']
#
#  add_48 (Add)                   (1, 901, 512)        0           ['multi_head_attention_13[0][0]',
#                                                                   'add_47[0][0]']
#
#  layer_normalization_28 (LayerN  (1, 901, 512)       1024        ['add_48[0][0]']
#  ormalization)
#
#  dense_31 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_28[0][0]']
#
#  dropout_27 (Dropout)           (1, 901, 3072)       0           ['dense_31[0][0]']
#
#  dense_32 (Dense)               (1, 901, 512)        1573376     ['dropout_27[0][0]']
#
#  dropout_28 (Dropout)           (1, 901, 512)        0           ['dense_32[0][0]']
#
#  add_49 (Add)                   (1, 901, 512)        0           ['dropout_28[0][0]',
#                                                                   'add_48[0][0]']
#
#  layer_normalization_29 (LayerN  (1, 901, 512)       1024        ['add_49[0][0]']
#  ormalization)
#
#  multi_head_attention_14 (Multi  (1, 901, 512)       10501632    ['layer_normalization_29[0][0]',
#  HeadAttention)                                                   'layer_normalization_29[0][0]']
#
#  add_50 (Add)                   (1, 901, 512)        0           ['multi_head_attention_14[0][0]',
#                                                                   'add_49[0][0]']
#
#  layer_normalization_30 (LayerN  (1, 901, 512)       1024        ['add_50[0][0]']
#  ormalization)
#
#  dense_33 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_30[0][0]']
#
#  dropout_29 (Dropout)           (1, 901, 3072)       0           ['dense_33[0][0]']
#
#  dense_34 (Dense)               (1, 901, 512)        1573376     ['dropout_29[0][0]']
#
#  dropout_30 (Dropout)           (1, 901, 512)        0           ['dense_34[0][0]']
#
#  add_51 (Add)                   (1, 901, 512)        0           ['dropout_30[0][0]',
#                                                                   'add_50[0][0]']
#
#  layer_normalization_31 (LayerN  (1, 901, 512)       1024        ['add_51[0][0]']
#  ormalization)
#
#  multi_head_attention_15 (Multi  (1, 901, 512)       10501632    ['layer_normalization_31[0][0]',
#  HeadAttention)                                                   'layer_normalization_31[0][0]']
#
#  add_52 (Add)                   (1, 901, 512)        0           ['multi_head_attention_15[0][0]',
#                                                                   'add_51[0][0]']
#
#  layer_normalization_32 (LayerN  (1, 901, 512)       1024        ['add_52[0][0]']
#  ormalization)
#
#  dense_35 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_32[0][0]']
#
#  dropout_31 (Dropout)           (1, 901, 3072)       0           ['dense_35[0][0]']
#
#  dense_36 (Dense)               (1, 901, 512)        1573376     ['dropout_31[0][0]']
#
#  dropout_32 (Dropout)           (1, 901, 512)        0           ['dense_36[0][0]']
#
#  add_53 (Add)                   (1, 901, 512)        0           ['dropout_32[0][0]',
#                                                                   'add_52[0][0]']
#
#  layer_normalization_33 (LayerN  (1, 901, 512)       1024        ['add_53[0][0]']
#  ormalization)
#
#  multi_head_attention_16 (Multi  (1, 901, 512)       10501632    ['layer_normalization_33[0][0]',
#  HeadAttention)                                                   'layer_normalization_33[0][0]']
#
#  add_54 (Add)                   (1, 901, 512)        0           ['multi_head_attention_16[0][0]',
#                                                                   'add_53[0][0]']
#
#  layer_normalization_34 (LayerN  (1, 901, 512)       1024        ['add_54[0][0]']
#  ormalization)
#
#  dense_37 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_34[0][0]']
#
#  dropout_33 (Dropout)           (1, 901, 3072)       0           ['dense_37[0][0]']
#
#  dense_38 (Dense)               (1, 901, 512)        1573376     ['dropout_33[0][0]']
#
#  dropout_34 (Dropout)           (1, 901, 512)        0           ['dense_38[0][0]']
#
#  add_55 (Add)                   (1, 901, 512)        0           ['dropout_34[0][0]',
#                                                                   'add_54[0][0]']
#
#  layer_normalization_35 (LayerN  (1, 901, 512)       1024        ['add_55[0][0]']
#  ormalization)
#
#  multi_head_attention_17 (Multi  (1, 901, 512)       10501632    ['layer_normalization_35[0][0]',
#  HeadAttention)                                                   'layer_normalization_35[0][0]']
#
#  add_56 (Add)                   (1, 901, 512)        0           ['multi_head_attention_17[0][0]',
#                                                                   'add_55[0][0]']
#
#  layer_normalization_36 (LayerN  (1, 901, 512)       1024        ['add_56[0][0]']
#  ormalization)
#
#  dense_39 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_36[0][0]']
#
#  dropout_35 (Dropout)           (1, 901, 3072)       0           ['dense_39[0][0]']
#
#  dense_40 (Dense)               (1, 901, 512)        1573376     ['dropout_35[0][0]']
#
#  dropout_36 (Dropout)           (1, 901, 512)        0           ['dense_40[0][0]']
#
#  add_57 (Add)                   (1, 901, 512)        0           ['dropout_36[0][0]',
#                                                                   'add_56[0][0]']
#
#  layer_normalization_37 (LayerN  (1, 901, 512)       1024        ['add_57[0][0]']
#  ormalization)
#
#  multi_head_attention_18 (Multi  (1, 901, 512)       10501632    ['layer_normalization_37[0][0]',
#  HeadAttention)                                                   'layer_normalization_37[0][0]']
#
#  add_58 (Add)                   (1, 901, 512)        0           ['multi_head_attention_18[0][0]',
#                                                                   'add_57[0][0]']
#
#  layer_normalization_38 (LayerN  (1, 901, 512)       1024        ['add_58[0][0]']
#  ormalization)
#
#  dense_41 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_38[0][0]']
#
#  dropout_37 (Dropout)           (1, 901, 3072)       0           ['dense_41[0][0]']
#
#  dense_42 (Dense)               (1, 901, 512)        1573376     ['dropout_37[0][0]']
#
#  dropout_38 (Dropout)           (1, 901, 512)        0           ['dense_42[0][0]']
#
#  add_59 (Add)                   (1, 901, 512)        0           ['dropout_38[0][0]',
#                                                                   'add_58[0][0]']
#
#  layer_normalization_39 (LayerN  (1, 901, 512)       1024        ['add_59[0][0]']
#  ormalization)
#
#  multi_head_attention_19 (Multi  (1, 901, 512)       10501632    ['layer_normalization_39[0][0]',
#  HeadAttention)                                                   'layer_normalization_39[0][0]']
#
#  add_60 (Add)                   (1, 901, 512)        0           ['multi_head_attention_19[0][0]',
#                                                                   'add_59[0][0]']
#
#  layer_normalization_40 (LayerN  (1, 901, 512)       1024        ['add_60[0][0]']
#  ormalization)
#
#  dense_43 (Dense)               (1, 901, 3072)       1575936     ['layer_normalization_40[0][0]']
#
#  dropout_39 (Dropout)           (1, 901, 3072)       0           ['dense_43[0][0]']
#
#  dense_44 (Dense)               (1, 901, 512)        1573376     ['dropout_39[0][0]']
#
#  dropout_40 (Dropout)           (1, 901, 512)        0           ['dense_44[0][0]']
#
#  add_61 (Add)                   (1, 901, 512)        0           ['dropout_40[0][0]',
#                                                                   'add_60[0][0]']
#
#  layer_normalization_41 (LayerN  (1, 901, 512)       1024        ['add_61[0][0]']
#  ormalization)
#
#  tf.__operators__.getitem_3 (Sl  (1, 512)            0           ['layer_normalization_41[0][0]']
#  icingOpLambda)
#
#  dropout_41 (Dropout)           (1, 512)             0           ['tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  dense_45 (Dense)               (1, 900)             461700      ['dropout_41[0][0]']
#
#  row (Dense)                    (1, 900)             810900      ['dense_45[0][0]']
#
#  col (Dense)                    (1, 900)             810900      ['dense_45[0][0]']
#
# ==================================================================================================
# Total params: 151,143,404
# Trainable params: 151,133,676
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %%
model.output_shape
# Out:
# [(1, 900), (1, 900)]

# %% [markdown]
# # data loader

# %%
import cv2
import numpy as np
import pandas as pd
from collections import defaultdict
import sys
import xml.etree.ElementTree as ET
from xml.dom import minidom
import requests
import tarfile

from os import path
from PIL import Image
from PIL import ImageFont, ImageDraw
from glob import glob
from matplotlib import pyplot as plt

from matplotlib.patches import  Rectangle
from PIL import ImageFont, ImageDraw
import tensorflow as tf
import ast

# %%
def convert_String_to_array(string_array):
    nested_list = ast.literal_eval(string_array)

    return nested_list

def normalize_img(img):
    #norm_img = (img - img.min()) / (img.max() - img.min())
    norm_img = np.array(img,dtype= np.float32)/255.0
    return norm_img

# %%
def get_cell_list(row, col):
    cell_list = []
    cord_list = []
    for idx_row, box_row in enumerate(row):
        x1_row, y1_row , x2_row, y2_row = box_row
        for idx_col, box_col in enumerate(col):
            x1_col, y1_col, x2_col, y2_col = box_col

            update_cell = [idx_row, idx_col, x1_col, y1_row, x2_col, y2_row]
            update_cord = [idx_row, idx_col]
            cell_list.append(update_cell)
            cord_list.append(update_cord)
    current_len = len(cell_list)
    cell_list = np.array(cell_list)
    # pad = (0, 2500-current_len)
    # cell_list_padded = np.pad(cell_list, (pad, (0,0)), mode= 'constant', constant_values= 0)
    return cell_list, cord_list

# %%
def box_feature_map(cell_list):
    new_cell_list = []
    for box in cell_list:
        x_pos, y_pos , x1 , y1 , x2 , y2 = box
        x1 = int((x1*64)/256)
        y1 = int((y1*64)/256)
        x2 = int((x2*64)/256)
        y2 = int((y2*64)/256)
        new_box = [x_pos, y_pos, x1, y1, x2, y2]
        new_cell_list.append(new_box)
    new_cell_list = np.array(new_cell_list)
    return new_cell_list

# %%
def load_data_input(file_name, col_bbox_list, row_bbox_list):
    col = convert_String_to_array(col_bbox_list)
    col =np.array(col)
    col = col[0]

    row= convert_String_to_array(row_bbox_list)
    row =np.array(row)
    row = row[0]


    img_path  = data_path + file_name + '.jpg'
    image = Image.open(img_path)
    image_np = np.array(image)
    image_np = cv2.resize(image_np, (256,256))
    image_np = np.array(image_np)

    cell_list, cord_list = get_cell_list(row, col)
    feature_map_cell = box_feature_map(cell_list) 


    return image_np, feature_map_cell

# %%
def pad_array(x):
    pad_h = (0,(MAX_- x.shape[0]))
    pad_w = (0, (MAX_- x.shape[1]))
    padded = np.pad(x, (pad_h, pad_w), mode= 'constant', constant_values= 0)
    return padded
def load_data_gt(file_name):
    row_arr = np.load(saved_txt_row_path + file_name + ".npy")
    col_arr = np.load(saved_txt_col_path + file_name + ".npy")
    
    row_arr_padded = pad_array(row_arr)
    col_arr_padded = pad_array(col_arr)
    row_arr_padded = np.reshape(row_arr_padded, (900))
    col_arr_padded = np.reshape(col_arr_padded, (900))
    return row_arr_padded, col_arr_padded

# %%
class DataGenerator(tf.keras.utils.Sequence) :
    def __init__(self, data_row, data_col , batch_size= 1,dim = 256, shuffle=True ):
        self.data_row= data_row
        self.data_col = data_col
        self.indices= self.data_row.index.tolist()
        self.batch_size = batch_size
        self.dim = dim
        self.shuffle = shuffle
        self.on_epoch_end()
    def __len__(self):
        return int(np.ceil(len(self.data_row) / self.batch_size))
    def __getitem__(self, index):
        if (index + 1) * self.batch_size > len(self.indices):
            self.batch_size = len(self.indices) - index * self.batch_size
        index = self.indices[index * self.batch_size : (index + 1) * self.batch_size]
        batch = [self.indices[k] for k in index]
        image_input_batch, feature_map_bbox_batch, gt_row_batch, gt_col_batch = self.data_generation(batch)
        return {"image" : image_input_batch, "bbox" : feature_map_bbox_batch} , {"row" :  gt_row_batch, "col": gt_col_batch}

    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))
        if self.shuffle == True:
            np.random.shuffle(self.index)

    def data_generation(self, batch):
        image_input_batch = np.empty((self.batch_size, self.dim , self.dim , 3))
        # feature_map_bbox_batch = np.empty((self.batch_size, 2500, 4))
        gt_row_batch = np.empty((self.batch_size, 900))
        gt_col_batch = np.empty((self.batch_size, 900))

        file_name = self.data_col.iloc[0][0]
        col_bbox_list = self.data_col.iloc[0][1]
        row_bbox_list = self.data_row.iloc[0][1]

        image_resized , feature_map_bbox = load_data_input(file_name, col_bbox_list, row_bbox_list)
        image_resized = normalize_img(image_resized)
        row_arr_padded, col_arr_padded = load_data_gt(file_name)

        image_input_batch[0] = image_resized
        feature_map_bbox_batch =np.expand_dims(feature_map_bbox , axis=0)

        gt_row_batch[0] = row_arr_padded
        gt_col_batch[0] = col_arr_padded


        return image_input_batch, feature_map_bbox_batch, gt_row_batch, gt_col_batch

# %%
data_path = 'D:/PubTables-1M-Structure_Images_Test/'
source_xml_path = 'D:/PubTables-1M-Structure_Annotations_Test/'
source_word_path ='D:/PubTables-1M-Structure_Table_Words/'

saved_txt_row_path ='D:/đề cương/merge/data_2/col/'
saved_txt_col_path ='D:/đề cương/merge/data_2/row/'

# %%
data_col = pd.read_csv('data_col.csv')
data_row = pd.read_csv('data_row.csv')

# %%
i = 0
input_, gt  = next(iter(DataGenerator(data_col=data_col[i:], data_row=data_row[i:])))

# %%
training_generator = DataGenerator(data_col=data_col[:10].reset_index(drop=True), data_row=data_row[:10].reset_index(drop=True))

# %%
history = model.fit(training_generator, epochs= 10)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 78s 8s/step - loss: 1.3188 - row_loss: 0.6597 - col_loss: 0.6591
# Epoch 2/10
# 10/10 [==============================] - 78s 8s/step - loss: 1.2995 - row_loss: 0.6500 - col_loss: 0.6494
# Epoch 3/10
# 10/10 [==============================] - 78s 8s/step - loss: 1.2805 - row_loss: 0.6405 - col_loss: 0.6399
# Epoch 4/10
# 10/10 [==============================] - 78s 8s/step - loss: 1.2618 - row_loss: 0.6312 - col_loss: 0.6306
# Epoch 5/10
# 10/10 [==============================] - 78s 8s/step - loss: 1.2435 - row_loss: 0.6221 - col_loss: 0.6215
# Epoch 6/10
# 10/10 [==============================] - 78s 8s/step - loss: 1.2255 - row_loss: 0.6130 - col_loss: 0.6125
# Epoch 7/10
# 10/10 [==============================] - 78s 8s/step - loss: 1.2078 - row_loss: 0.6042 - col_loss: 0.6036
# Epoch 8/10
# 10/10 [==============================] - 77s 8s/step - loss: 1.1904 - row_loss: 0.5955 - col_loss: 0.5949
# Epoch 9/10
# 10/10 [==============================] - 77s 8s/step - loss: 1.1732 - row_loss: 0.5869 - col_loss: 0.5863
# Epoch 10/10
# 10/10 [==============================] - 77s 8s/step - loss: 1.1564 - row_loss: 0.5785 - col_loss: 0.5779
